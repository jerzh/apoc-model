# %%
import pandas as pd
df = pd.read_csv('data-CD-Oncho-iu.csv')

# %%
df = df[df['Year'] == 2019]

# %%
with pd.option_context('display.max_columns', None):
    display(df)
# Out:
#      CONTINENT         REGION WHO_REGION                            ADMIN0  \
# 6       Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 14      Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 22      Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 30      Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 38      Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# ...        ...            ...        ...                               ...
# 4118    Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 4126    Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 4134    Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 4142    Africa  Middle Africa       AFRO  Democratic Republic of the Congo
# 4150    Africa  Middle Africa       AFRO  Democratic Republic of the Congo
#
#       ADMIN0ID ADMIN0_FIP ADMIN0ISO2 ADMIN0ISO3         ADMIN1  ADMIN1ID  \
# 6           14         CG         CD        COD          Kwilu     24753
# 14          14         CG         CD        COD          Kwilu     24753
# 22          14         CG         CD        COD         Kwango     24752
# 30          14         CG         CD        COD     Mai-Ndombe     24754
# 38          14         CG         CD        COD     Mai-Ndombe     24754
# ...        ...        ...        ...        ...            ...       ...
# 4118        14         CG         CD        COD          Kwilu     24753
# 4126        14         CG         CD        COD        Sankuru     24767
# 4134        14         CG         CD        COD   Haut-Katanga     26059
# 4142        14         CG         CD        COD  Kasai-Central     24765
# 4150        14         CG         CD        COD          Kasai     24764
#
#             ADMIN2  ADMIN2ID  Alt_ADMIN2      ADMIN3  ADMIN3ID IUs_ADM  \
# 6           Bagata         0         NaN      Bagata     13816    ADM3
# 14        Bandundu         0         NaN    Bandundu     13818    ADM3
# 22           Kenge         0         NaN        Boko     13819    ADM3
# 30            Kutu         0         NaN      Bokoro     13820    ADM3
# 38          Bolobo         0         NaN      Bolobo     13821    ADM3
# ...            ...       ...         ...         ...       ...     ...
# 4118  Masi-Manimba         0         NaN  Bongayassa     14335    ADM3
# 4126        Lubefu         0         NaN     Dikungu     14336    ADM3
# 4134       Kasenga         0         NaN    Kashobwe     14337    ADM3
# 4142        Dibaya         0         NaN    Bunkonde     14338    ADM3
# 4150       Kamonia         0         NaN     Kamonia     14340    ADM3
#
#         IUs_NAME  IU_ID        IU_CODE  Year  PopTot  PopPreSAC  PopSAC  \
# 6         Bagata  13816  COD2475313816  2019  203103      34528   71086
# 14      Bandundu  13818  COD2475313818  2019  189523      32219   66333
# 22          Boko  13819  COD2475213819  2019  292409      49710  102343
# 30        Bokoro  13820  COD2475413820  2019  259679      44145   90888
# 38        Bolobo  13821  COD2475413821  2019  149070      25342   52175
# ...          ...    ...            ...   ...     ...        ...     ...
# 4118  Yasa-Bonga  14335  COD2475314335  2019  235782      40083   82524
# 4126     Dikungu  14336  COD2476714336  2019  181491      30853   63522
# 4134    Kashobwe  14337  COD2605914337  2019  168007      28561   58802
# 4142    Bunkonde  14338  COD2476514338  2019  119592      20331   41857
# 4150     Kamonia  14340  COD2476414340  2019  461270      78416  161445
#
#       PopAdult                                    Endemicity  PopReq  PopTrg  \
# 6        93427                        Unknown (under LF MDA)       0       0
# 14       87181                        Unknown (under LF MDA)       0       0
# 22      134508                           Endemic (under MDA)  292409  236851
# 30      119452  Unknown (consider Oncho Elimination Mapping)       0       0
# 38       68572  Unknown (consider Oncho Elimination Mapping)       0       0
# ...        ...                                           ...     ...     ...
# 4118    108460                           Endemic (under MDA)  235782  190984
# 4126     83486                           Endemic (under MDA)  181491  147008
# 4134     77283  Unknown (consider Oncho Elimination Mapping)       0       0
# 4142     55012                           Endemic (under MDA)  119592   96869
# 4150    212184                           Endemic (under MDA)  461270  373629
#
#       PopTreat     Cov  Cum_MDA  MDA  EffMDA  MDA_n  EffMDA_n  EpiCov  EpiMDA  \
# 6            0    0.00        4    0       0      1         1    0.00       0
# 14           0    0.00        4    0       0      1         1    0.00       0
# 22      236868  100.01        6    1       1      4         4   81.01       1
# 30           0    0.00        0    0       0      0         0    0.00       0
# 38           0    0.00        0    0       0      0         0    0.00       0
# ...        ...     ...      ...  ...     ...    ...       ...     ...     ...
# 4118    192070  100.57       16    1       1      5         5   81.46       1
# 4126    147755  100.51       18    1       1      6         6   81.41       1
# 4134         0    0.00        0    0       0      0         0    0.00       0
# 4142     97429  100.58       21    1       1      6         5   81.47       1
# 4150    374197  100.15       21    1       1      6         6   81.12       1
#
#       EpiEffMDA  EpiMDA_n  EpiEffMDA_n     MDA_scheme  Endemicity_ID
# 6             0         1            1  Not delivered              5
# 14            0         1            1  Not delivered              5
# 22            1         4            3            IVM              2
# 30            0         0            0  Not delivered              4
# 38            0         0            0  Not delivered              4
# ...         ...       ...          ...            ...            ...
# 4118          1         5            2            IVM              2
# 4126          1         6            5            IVM              2
# 4134          0         0            0  Not delivered              4
# 4142          1         6            5            IVM              2
# 4150          1         6            6        ALB+IVM              2
#
# [519 rows x 41 columns]

# %%
len(df)
# Out:
# 519

# %%
sum(df['PopReq']) - sum(df['PopTreat'])
# Out:
# 9555127
